# %% [markdown]
# Lo más importante es empezar con el
# # Análisis y Limpieza de Datos

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df=pd.read_csv("data_evaluacion.csv")

# %%
df.head(10)
# Out:
#    39         State-gov   77516     Bachelors    13          Never-married  \
# 0  50  Self-emp-not-inc   83311     Bachelors  13.0     Married-civ-spouse
# 1  38           Private  215646       HS-grad   9.0               Divorced
# 2  53           Private  234721          11th   7.0     Married-civ-spouse
# 3  28           Private  338409     Bachelors  13.0     Married-civ-spouse
# 4  37           Private  284582       Masters  14.0     Married-civ-spouse
# 5  49           Private  160187           9th   5.0  Married-spouse-absent
# 6  52  Self-emp-not-inc  209642       HS-grad   9.0     Married-civ-spouse
# 7  31           Private   45781       Masters  14.0          Never-married
# 8  42           Private  159449     Bachelors  13.0     Married-civ-spouse
# 9  37           Private  280464  Some-college  10.0     Married-civ-spouse
#
#         Adm-clerical  Not-in-family  White    Male     2174    0    40  \
# 0    Exec-managerial        Husband  White    Male      0.0  0.0  13.0
# 1  Handlers-cleaners  Not-in-family  White    Male      0.0  0.0  40.0
# 2  Handlers-cleaners        Husband  Black    Male      0.0  0.0  40.0
# 3     Prof-specialty           Wife  Black  Female      0.0  0.0  40.0
# 4    Exec-managerial           Wife  White  Female      0.0  0.0  40.0
# 5      Other-service  Not-in-family  Black  Female      0.0  0.0  16.0
# 6    Exec-managerial        Husband  White    Male      0.0  0.0  45.0
# 7     Prof-specialty  Not-in-family  White  Female  14084.0  0.0  50.0
# 8    Exec-managerial        Husband  White    Male   5178.0  0.0  40.0
# 9    Exec-managerial        Husband  Black    Male      0.0  0.0  80.0
#
#    United-States  <=50K
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3           Cuba  <=50K
# 4  United-States  <=50K
# 5        Jamaica  <=50K
# 6  United-States   >50K
# 7  United-States   >50K
# 8  United-States   >50K
# 9  United-States   >50K

# %%
#Le añado nombres a las columnas para poder identificarlas mejor, hay ciertos componentes que no tengo idea de qué tratan así que los nombro como comp#
df.columns = ['edad', 'institucion-trabajo', 'comp1', 'estudios', 'comp2',
              'estado-civil', 'ocupacion', 'relacion-familiar', 'raza',
              'genero', 'comp3', 'comp4', 'horas-semana', 'pais', 'ingresos-anuales']
df.head()
# Out:
#    edad institucion-trabajo   comp1   estudios  comp2        estado-civil  \
# 0    50    Self-emp-not-inc   83311  Bachelors   13.0  Married-civ-spouse
# 1    38             Private  215646    HS-grad    9.0            Divorced
# 2    53             Private  234721       11th    7.0  Married-civ-spouse
# 3    28             Private  338409  Bachelors   13.0  Married-civ-spouse
# 4    37             Private  284582    Masters   14.0  Married-civ-spouse
#
#            ocupacion relacion-familiar   raza  genero  comp3  comp4  \
# 0    Exec-managerial           Husband  White    Male    0.0    0.0
# 1  Handlers-cleaners     Not-in-family  White    Male    0.0    0.0
# 2  Handlers-cleaners           Husband  Black    Male    0.0    0.0
# 3     Prof-specialty              Wife  Black  Female    0.0    0.0
# 4    Exec-managerial              Wife  White  Female    0.0    0.0
#
#    horas-semana           pais ingresos-anuales
# 0          13.0  United-States            <=50K
# 1          40.0  United-States            <=50K
# 2          40.0  United-States            <=50K
# 3          40.0           Cuba            <=50K
# 4          40.0  United-States            <=50K

# %%
df.shape
# Out:
# (9714, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9714 entries, 0 to 9713
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   edad                 9714 non-null   int64
#  1   institucion-trabajo  9714 non-null   object
#  2   comp1                9714 non-null   int64
#  3   estudios             9714 non-null   object
#  4   comp2                9713 non-null   float64
#  5   estado-civil         9713 non-null   object
#  6   ocupacion            9713 non-null   object
#  7   relacion-familiar    9713 non-null   object
#  8   raza                 9713 non-null   object
#  9   genero               9713 non-null   object
#  10  comp3                9713 non-null   float64
#  11  comp4                9713 non-null   float64
#  12  horas-semana         9713 non-null   float64
#  13  pais                 9713 non-null   object
#  14  ingresos-anuales     9713 non-null   object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
#Voy a identificar si existen datos duplicados, y si los hay, los eliminamos.
def eliminar_duplicados(df):
  print("Número de filas duplicadas: ", df.duplicated().sum())
  if df.duplicated().sum() > 0:
    df.drop_duplicates(inplace=True)
    print("Nuevo número de filas: ", df.shape[0])
  else:
    print("No hay filas duplicadas.")
  return df

df = eliminar_duplicados(df)
# Out:
# Número de filas duplicadas:  3
# Nuevo número de filas:  9711

# %%
filas_con_interrogacion = df[df.apply(lambda row: row.astype(str).str.contains('\?').any(), axis=1)]
num_filas_con_interrogacion = filas_con_interrogacion.shape[0]
print("N° Filas con al menos un signo de interrogación:", num_filas_con_interrogacion)
# Out:
# N° Filas con al menos un signo de interrogación: 740

# %%
#Me doy cuenta que son muchas filas entonces no puedo borrarlas como tal, por ende voy a cambiarlas con otro valor.
df[df == '?'] = np.nan
for col in ['institucion-trabajo', 'ocupacion', 'pais']:df[col].fillna(df[col].mode()[0], inplace=True)

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Valores del DataFrame')
plt.show()

# %%
#Voy a obtener ahora información general de cómo se relacionan los datos entre sí de mi dataframe con los datos que no son objetos
df.describe()
# Out:
#               edad         comp1        comp2         comp3        comp4  \
# count  9711.000000  9.711000e+03  9710.000000   9710.000000  9710.000000
# mean     38.423231  1.903632e+05    10.071988   1062.205973    88.550772
# std      13.570583  1.056483e+05     2.546158   7301.099317   402.664323
# min      17.000000  1.930200e+04     1.000000      0.000000     0.000000
# 25%      28.000000  1.185755e+05     9.000000      0.000000     0.000000
# 50%      37.000000  1.790100e+05    10.000000      0.000000     0.000000
# 75%      47.000000  2.385925e+05    12.000000      0.000000     0.000000
# max      90.000000  1.226583e+06    16.000000  99999.000000  4356.000000
#
#        horas-semana
# count   9710.000000
# mean      40.510402
# std       12.261512
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
#Voy a obtener ahora información general de cómo se relacionan los datos entre sí de mi dataframe que son objetos
df.describe(include='object')
# Out:
#        institucion-trabajo estudios        estado-civil       ocupacion  \
# count                 9711     9711                9710            9711
# unique                   8       16                   7              14
# top                Private  HS-grad  Married-civ-spouse  Prof-specialty
# freq                  7321     3139                4427            1793
#
#        relacion-familiar   raza genero           pais ingresos-anuales
# count               9710   9710   9710           9711             9710
# unique                 6      5      2             40                2
# top              Husband  White   Male  United-States            <=50K
# freq                3890   8312   6507           8862             7403

# %%
#Para poder manejar mejor mis datos nos dimos cuenta que en el apartado relacion-familiar, tenemos Husband a Wife y eso puede generar dispersión en los datos pero al final son lo mismo
#Entonces voy a unificar ambos como Casado -> Married y así evitar la dispersión, porque al final son lo mismo y me permite obtener una precisión más alta
df['relacion-familiar'] = df['relacion-familiar'].replace(['Wife','Husband'],'Married')

# %%
#Voy a analizar la manera en la que puedo encodear y organizar mis datos de estado civil
df['estado-civil'].value_counts()
df.head(20)
# Out:
#     edad institucion-trabajo   comp1      estudios  comp2  \
# 0     50    Self-emp-not-inc   83311     Bachelors   13.0
# 1     38             Private  215646       HS-grad    9.0
# 2     53             Private  234721          11th    7.0
# 3     28             Private  338409     Bachelors   13.0
# 4     37             Private  284582       Masters   14.0
# 5     49             Private  160187           9th    5.0
# 6     52    Self-emp-not-inc  209642       HS-grad    9.0
# 7     31             Private   45781       Masters   14.0
# 8     42             Private  159449     Bachelors   13.0
# 9     37             Private  280464  Some-college   10.0
# 10    30           State-gov  141297     Bachelors   13.0
# 11    23             Private  122272     Bachelors   13.0
# 12    32             Private  205019    Assoc-acdm   12.0
# 13    40             Private  121772     Assoc-voc   11.0
# 14    34             Private  245487       7th-8th    4.0
# 15    25    Self-emp-not-inc  176756       HS-grad    9.0
# 16    32             Private  186824       HS-grad    9.0
# 17    38             Private   28887          11th    7.0
# 18    43    Self-emp-not-inc  292175       Masters   14.0
# 19    40             Private  193524     Doctorate   16.0
#
#              estado-civil          ocupacion relacion-familiar  \
# 0      Married-civ-spouse    Exec-managerial           Married
# 1                Divorced  Handlers-cleaners     Not-in-family
# 2      Married-civ-spouse  Handlers-cleaners           Married
# 3      Married-civ-spouse     Prof-specialty           Married
# 4      Married-civ-spouse    Exec-managerial           Married
# 5   Married-spouse-absent      Other-service     Not-in-family
# 6      Married-civ-spouse    Exec-managerial           Married
# 7           Never-married     Prof-specialty     Not-in-family
# 8      Married-civ-spouse    Exec-managerial           Married
# 9      Married-civ-spouse    Exec-managerial           Married
# 10     Married-civ-spouse     Prof-specialty           Married
# 11          Never-married       Adm-clerical         Own-child
# 12          Never-married              Sales     Not-in-family
# 13     Married-civ-spouse       Craft-repair           Married
# 14     Married-civ-spouse   Transport-moving           Married
# 15          Never-married    Farming-fishing         Own-child
# 16          Never-married  Machine-op-inspct         Unmarried
# 17     Married-civ-spouse              Sales           Married
# 18               Divorced    Exec-managerial         Unmarried
# 19     Married-civ-spouse     Prof-specialty           Married
#
#                   raza  genero    comp3  comp4  horas-semana           pais  \
# 0                White    Male      0.0    0.0          13.0  United-States
# 1                White    Male      0.0    0.0          40.0  United-States
# 2                Black    Male      0.0    0.0          40.0  United-States
# 3                Black  Female      0.0    0.0          40.0           Cuba
# 4                White  Female      0.0    0.0          40.0  United-States
# 5                Black  Female      0.0    0.0          16.0        Jamaica
# 6                White    Male      0.0    0.0          45.0  United-States
# 7                White  Female  14084.0    0.0          50.0  United-States
# 8                White    Male   5178.0    0.0          40.0  United-States
# 9                Black    Male      0.0    0.0          80.0  United-States
# 10  Asian-Pac-Islander    Male      0.0    0.0          40.0          India
# 11               White  Female      0.0    0.0          30.0  United-States
# 12               Black    Male      0.0    0.0          50.0  United-States
# 13  Asian-Pac-Islander    Male      0.0    0.0          40.0  United-States
# 14  Amer-Indian-Eskimo    Male      0.0    0.0          45.0         Mexico
# 15               White    Male      0.0    0.0          35.0  United-States
# 16               White    Male      0.0    0.0          40.0  United-States
# 17               White    Male      0.0    0.0          50.0  United-States
# 18               White  Female      0.0    0.0          45.0  United-States
# 19               White    Male      0.0    0.0          60.0  United-States
#
#    ingresos-anuales
# 0             <=50K
# 1             <=50K
# 2             <=50K
# 3             <=50K
# 4             <=50K
# 5             <=50K
# 6              >50K
# 7              >50K
# 8              >50K
# 9              >50K
# 10             >50K
# 11            <=50K
# 12            <=50K
# 13             >50K
# 14            <=50K
# 15            <=50K
# 16            <=50K
# 17            <=50K
# 18             >50K
# 19             >50K

# %%
#Voy a ver mediante una matriz de correlación qué tanta relación tienen mis valores numéricos
correlation_matrix = df.select_dtypes(include=['number']).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación')
plt.show()

# %%
#Empiezo encodeando mis valores objetivo, en este caso 1 -> Gana más o igual a 50k al año, caso 2-> Gana menos de 50K al año
df['ingresos-anuales'] = df['ingresos-anuales'].apply(lambda x: 1 if x == '<=50K' else 0)

# %%
#Mediante un encoding voy a codificar mis variables categóricas para convertirlas en numéricas, en este caso se aplican a todas las filas que no son números
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in df.select_dtypes(include=['object']):
  df[column] = label_encoder.fit_transform(df[column])

print(df.head())
# Out:
#    edad  institucion-trabajo   comp1  estudios  comp2  estado-civil  \
# 0    50                    5   83311         9   13.0             2
# 1    38                    3  215646        11    9.0             0
# 2    53                    3  234721         1    7.0             2
# 3    28                    3  338409         9   13.0             2
# 4    37                    3  284582        12   14.0             2
#
#    ocupacion  relacion-familiar  raza  genero  comp3  comp4  horas-semana  \
# 0          3                  0     4       1    0.0    0.0          13.0
# 1          5                  1     4       1    0.0    0.0          40.0
# 2          5                  0     2       1    0.0    0.0          40.0
# 3          9                  0     2       0    0.0    0.0          40.0
# 4          3                  0     4       0    0.0    0.0          40.0
#
#    pais  ingresos-anuales
# 0    37                 1
# 1    37                 1
# 2    37                 1
# 3     4                 1
# 4    37                 1

# %%
df.head(20)
# Out:
#     edad  institucion-trabajo   comp1  estudios  comp2  estado-civil  \
# 0     50                    5   83311         9   13.0             2
# 1     38                    3  215646        11    9.0             0
# 2     53                    3  234721         1    7.0             2
# 3     28                    3  338409         9   13.0             2
# 4     37                    3  284582        12   14.0             2
# 5     49                    3  160187         6    5.0             3
# 6     52                    5  209642        11    9.0             2
# 7     31                    3   45781        12   14.0             4
# 8     42                    3  159449         9   13.0             2
# 9     37                    3  280464        15   10.0             2
# 10    30                    6  141297         9   13.0             2
# 11    23                    3  122272         9   13.0             4
# 12    32                    3  205019         7   12.0             4
# 13    40                    3  121772         8   11.0             2
# 14    34                    3  245487         5    4.0             2
# 15    25                    5  176756        11    9.0             4
# 16    32                    3  186824        11    9.0             4
# 17    38                    3   28887         1    7.0             2
# 18    43                    5  292175        12   14.0             0
# 19    40                    3  193524        10   16.0             2
#
#     ocupacion  relacion-familiar  raza  genero    comp3  comp4  horas-semana  \
# 0           3                  0     4       1      0.0    0.0          13.0
# 1           5                  1     4       1      0.0    0.0          40.0
# 2           5                  0     2       1      0.0    0.0          40.0
# 3           9                  0     2       0      0.0    0.0          40.0
# 4           3                  0     4       0      0.0    0.0          40.0
# 5           7                  1     2       0      0.0    0.0          16.0
# 6           3                  0     4       1      0.0    0.0          45.0
# 7           9                  1     4       0  14084.0    0.0          50.0
# 8           3                  0     4       1   5178.0    0.0          40.0
# 9           3                  0     2       1      0.0    0.0          80.0
# 10          9                  0     1       1      0.0    0.0          40.0
# 11          0                  3     4       0      0.0    0.0          30.0
# 12         11                  1     2       1      0.0    0.0          50.0
# 13          2                  0     1       1      0.0    0.0          40.0
# 14         13                  0     0       1      0.0    0.0          45.0
# 15          4                  3     4       1      0.0    0.0          35.0
# 16          6                  4     4       1      0.0    0.0          40.0
# 17         11                  0     4       1      0.0    0.0          50.0
# 18          3                  4     4       0      0.0    0.0          45.0
# 19          9                  0     4       1      0.0    0.0          60.0
#
#     pais  ingresos-anuales
# 0     37                 1
# 1     37                 1
# 2     37                 1
# 3      4                 1
# 4     37                 1
# 5     21                 1
# 6     37                 0
# 7     37                 0
# 8     37                 0
# 9     37                 0
# 10    17                 0
# 11    37                 1
# 12    37                 1
# 13    37                 0
# 14    24                 1
# 15    37                 1
# 16    37                 1
# 17    37                 1
# 18    37                 0
# 19    37                 0

# %%
#Tengo todo encodeado, entonces genero una matriz de correlación final para analizar cómo se relacionan las variables.
correlation_matrix = df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación')
plt.show()
#Me doy cuenta que no existe una correlación fuerte entre las variables, pero al cambiar Husband/Wife por Married obtenemos una correlación mayor.

# %%
#Voy a normalizar todos mis datos:
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
print(df_normalized.head())
# Out:
#        edad  institucion-trabajo     comp1  estudios     comp2  estado-civil  \
# 0  0.452055             0.714286  0.053019  0.600000  0.800000      0.285714
# 1  0.287671             0.428571  0.162633  0.733333  0.533333      0.000000
# 2  0.493151             0.428571  0.178433  0.066667  0.400000      0.285714
# 3  0.150685             0.428571  0.264319  0.600000  0.800000      0.285714
# 4  0.273973             0.428571  0.219733  0.800000  0.866667      0.285714
#
#    ocupacion  relacion-familiar  raza  genero  comp3  comp4  horas-semana  \
# 0   0.230769                0.0   0.8     0.5    0.0    0.0      0.122449
# 1   0.384615                0.2   0.8     0.5    0.0    0.0      0.397959
# 2   0.384615                0.0   0.4     0.5    0.0    0.0      0.397959
# 3   0.692308                0.0   0.4     0.0    0.0    0.0      0.397959
# 4   0.230769                0.0   0.8     0.0    0.0    0.0      0.397959
#
#        pais  ingresos-anuales
# 0  0.948718               1.0
# 1  0.948718               1.0
# 2  0.948718               1.0
# 3  0.102564               1.0
# 4  0.948718               1.0

# %%
#Puesto que no conozco sobre qué se refieren los comp#, y no presentan una correlación fuerte entre los datos

# %%
# Para decidir si usar la media o la moda para llenar los valores faltantes en 'comp1',
# primero debemos entender la distribución de los datos y si hay valores atípicos.

plt.figure(figsize=(10, 6))
sns.histplot(df['comp1'], kde=True)
plt.title('Distribución de comp1')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(df['comp1'])
plt.title('Boxplot de comp1')
plt.show()


media_comp1 = df['comp1'].mean()
moda_comp1 = df['comp1'].mode()[0]

print("Media de comp1:", media_comp1)
print("Moda de comp1:", moda_comp1)
# Out:
# Media de comp1: 190363.20214190093
# Moda de comp1: 121124

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['comp2'], kde=True)
plt.title('Distribución de comp2')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(df['comp2'])
plt.title('Boxplot de comp2')
plt.show()

media_comp2 = df['comp2'].mean()
moda_comp2 = df['comp2'].mode()[0]

print("Media de comp2:", media_comp2)
print("Moda de comp2:", moda_comp2)

conteo_valores = df['comp2'].value_counts()
print("Valores más frecuentes:\n", conteo_valores.head())
# Out:
# Media de comp2: 10.071987641606592
# Moda de comp2: 9.0
# Valores más frecuentes:
#  comp2
# 9.0     3138
# 10.0    2235
# 13.0    1583
# 14.0     511
# 11.0     408
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['comp3'], kde=True)
plt.title('Distribución de comp3')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(df['comp3'])
plt.title('Boxplot de comp3')
plt.show()

media_comp3 = df['comp3'].mean()
moda_comp3 = df['comp3'].mode()[0]

print("Media de comp3:", media_comp3)
print("Moda de comp3:", moda_comp3)

print("\nValores más repetidos en 'comp3':")
print(df['comp3'].value_counts().head(10))
# Out:
# Media de comp3: 1062.205973223481
# Moda de comp3: 0.0
#
# Valores más repetidos en 'comp3':
# comp3
# 0.0        8912
# 15024.0     110
# 7688.0       82
# 7298.0       65
# 99999.0      46
# 4386.0       27
# 3103.0       26
# 5013.0       24
# 5178.0       21
# 8614.0       20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['comp4'], kde=True)
plt.title('Distribución de comp4')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(df['comp4'])
plt.title('Boxplot de comp4')
plt.show()

media_comp4 = df['comp4'].mean()
mediana_comp4 = df['comp4'].median()
moda_comp4 = df['comp4'].mode()[0]

print("Media de comp4:", media_comp4)
print("Mediana de comp4:", mediana_comp4)
print("Moda de comp4:", moda_comp4)

print("\nValores más repetidos en 'comp4':")
print(df['comp4'].value_counts().head(10))
# Out:
# Media de comp4: 88.55077239958806
# Mediana de comp4: 0.0
# Moda de comp4: 0.0
#
# Valores más repetidos en 'comp4':
# comp4
# 0.0       9247
# 1902.0      69
# 1977.0      53
# 1887.0      37
# 1485.0      18
# 1590.0      16
# 1672.0      16
# 1740.0      14
# 1848.0      14
# 2415.0      14
# Name: count, dtype: int64

# %% [markdown]
# ### Este análisis de compN° se hace porque:
# No conocemos a qué exactamente pertenecen estos componentes, por ende a la hora de crear la interfaz gráfica y el despliegue no podemos pedirle llenar al usuario con dichos datos, por ende en base a los gráficos para:
# 1. comp1: Vamos a llenar automáticamente con la media
# 2. comp2: Vamos a llenar automáticamente con la media.
# 3. comp3: Vamos a llenar automáticamente con la moda.
# 4. comp4: Vamos a llenar automáticamente con la moda.

# %%
def exportar_df_a_csv(df, nombre_archivo):
  """
  Exporta un DataFrame de pandas a un archivo CSV.

  Args:
    df: El DataFrame a exportar.
    nombre_archivo: El nombre del archivo CSV a crear.
  """
  df.to_csv(nombre_archivo, index=False)
  print(f"DataFrame exportado a '{nombre_archivo}' con éxito.")

exportar_df_a_csv(df, 'databaseFinal.csv')
# Out:
# DataFrame exportado a 'databaseFinal.csv' con éxito.

# %%
data = pd.read_csv("databaseFinal.csv")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = data.drop(columns=['ingresos-anuales'])
y = data['ingresos-anuales']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7768, 14), (1943, 14), (7768,), (1943,))

# %% [markdown]
# # ENTRENO MI MODELO

# %%
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Crear el imputer para reemplazar NaN con la media de la columna
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Crear el modelo GaussianNB
model_nb = GaussianNB()

# Entrenar el modelo
model_nb.fit(X_train, y_train)

# Hacer predicciones
y_pred = model_nb.predict(X_test)

# Calcular la precisión
accuracy = accuracy_score(y_test, y_pred)

# Crear la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)

# Imprimir resultados
print(f'Precisión: {accuracy}')
print('Matriz de Confusión:')
print(conf_matrix)
print('Reporte de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# Precisión: 0.8023674729799279
# Matriz de Confusión:
# [[ 138  325]
#  [  59 1421]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.70      0.30      0.42       463
#            1       0.81      0.96      0.88      1480
#
#     accuracy                           0.80      1943
#    macro avg       0.76      0.63      0.65      1943
# weighted avg       0.79      0.80      0.77      1943
